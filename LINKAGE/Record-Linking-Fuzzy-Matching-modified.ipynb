# %% [markdown]
# ## Python Tools for Record Linking and Fuzzy Matching
#
# This notebook accompanies the [article](https://pbpython.com/record-linking.html) on Practical Business Python
#
# This notebook relies on [fuzzymatcher](https://github.com/RobinL/fuzzymatcher) and the [Python Record Linkage Toolkit](https://recordlinkage.readthedocs.io/en/latest/about.html)

# %% [markdown]
# ## first install the required packages

# %%
# !pip install fuzzymatcher
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fuzzymatcher
#   Downloading fuzzymatcher-0.0.6-py3-none-any.whl (15 kB)
# Collecting metaphone
#   Downloading Metaphone-0.6.tar.gz (14 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from fuzzymatcher) (1.3.5)
# Collecting rapidfuzz
#   Downloading rapidfuzz-2.11.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 13.6 MB/s
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.20.5-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from fuzzymatcher) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fuzzymatcher) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fuzzymatcher) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->fuzzymatcher) (1.15.0)
# Collecting Levenshtein==0.20.5
#   Downloading Levenshtein-0.20.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (170 kB)
#      |████████████████████████████████| 170 kB 94.0 MB/s
# Building wheels for collected packages: metaphone
#   Building wheel for metaphone (setup.py) ... done
#   Created wheel for metaphone: filename=Metaphone-0.6-py3-none-any.whl size=13918 sha256=4bbf79de9a775e3d1c4888fdaa8f7f2aa419a6ba8fa7863fcffa6d54c5991d95
#   Stored in directory: /root/.cache/pip/wheels/1d/a8/cb/6f8902aa5457bd71344e00665c230e9c45255b3f57f2194a0f
# Successfully built metaphone
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein, metaphone, fuzzymatcher
# Successfully installed Levenshtein-0.20.5 fuzzymatcher-0.0.6 metaphone-0.6 python-Levenshtein-0.20.5 rapidfuzz-2.11.0

# %%
pip install splink
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting splink
#   Downloading splink-3.3.9-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 14.2 MB/s
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from splink) (1.3.5)
# Collecting sqlglot==5.1.0
#   Downloading sqlglot-5.1.0-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 67.1 MB/s
# Collecting Jinja2<4.0.0,>=3.0.3
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 75.1 MB/s
# Requirement already satisfied: altair<5.0.0,>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from splink) (4.2.0)
# Collecting jsonschema<4.0,>=3.2
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.7 MB/s
# Collecting duckdb<0.6.0,>=0.5.0
#   Downloading duckdb-0.5.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      |████████████████████████████████| 16.4 MB 43.2 MB/s
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair<5.0.0,>=4.2.0->splink) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair<5.0.0,>=4.2.0->splink) (0.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from altair<5.0.0,>=4.2.0->splink) (1.21.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from Jinja2<4.0.0,>=3.0.3->splink) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<4.0,>=3.2->splink) (22.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema<4.0,>=3.2->splink) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema<4.0,>=3.2->splink) (4.12.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<4.0,>=3.2->splink) (0.18.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<4.0,>=3.2->splink) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.0.0->splink) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.0.0->splink) (2022.2.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema<4.0,>=3.2->splink) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema<4.0,>=3.2->splink) (3.8.1)
# Installing collected packages: jsonschema, Jinja2, sqlglot, duckdb, splink
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# Successfully installed Jinja2-3.1.2 duckdb-0.5.1 jsonschema-3.2.0 splink-3.3.9 sqlglot-5.1.0

# %%
# !pip install recordlinkage
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting recordlinkage
#   Downloading recordlinkage-0.15-py3-none-any.whl (926 kB)
#      |████████████████████████████████| 926 kB 12.8 MB/s
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from recordlinkage) (1.21.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from recordlinkage) (1.1.0)
# Requirement already satisfied: scipy>=1 in /usr/local/lib/python3.7/dist-packages (from recordlinkage) (1.7.3)
# Collecting jellyfish>=0.8.0
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 69.8 MB/s
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from recordlinkage) (1.0.2)
# Requirement already satisfied: pandas<2,>=1 in /usr/local/lib/python3.7/dist-packages (from recordlinkage) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2,>=1->recordlinkage) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2,>=1->recordlinkage) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas<2,>=1->recordlinkage) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.0->recordlinkage) (3.1.0)
# Building wheels for collected packages: jellyfish
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=74015 sha256=28277a2dd6abf894d0c40b5f553e5e5a595b02851b68514ceaf17ad9e40ec1b0
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built jellyfish
# Installing collected packages: jellyfish, recordlinkage
# Successfully installed jellyfish-0.9.0 recordlinkage-0.15

# %% [markdown]
# ## standard imports

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## data load is the same for each package

# %%
hospital_accounts = pd.read_csv(
    'https://github.com/chris1610/pbpython/raw/master/data/hospital_account_info.csv'
)
hospital_reimbursement = pd.read_csv(
    'https://raw.githubusercontent.com/chris1610/pbpython/master/data/hospital_reimbursement.csv'
)

# %%
hospital_accounts.head()
# Out:
#    Account_Num                      Facility Name                    Address  \
# 0        10605             SAGE MEMORIAL HOSPITAL  STATE ROUTE 264 SOUTH 191
# 1        24250        WOODRIDGE BEHAVIORAL CENTER       600 NORTH 7TH STREET
# 2        10341           DOUGLAS GARDENS HOSPITAL            5200 NE 2ND AVE
# 3        81101  SUNCOAST BEHAVIORAL HEALTH CENTER             4480 51ST ST W
# 4        39835           TREASURE VALLEY HOSPITAL   8800 WEST EMERALD STREET
#
#            City State  ZIP Code County Name    Phone Number  \
# 0        GANADO    AZ     86505      APACHE  (928) 755-4541
# 1  WEST MEMPHIS    AR     72301  CRITTENDEN  (870) 394-4113
# 2         MIAMI    FL     33137  MIAMI-DADE  (305) 751-8626
# 3     BRADENTON    FL     34210     MANATEE  (941) 792-2222
# 4         BOISE    ID     83704         ADA  (208) 373-5000
#
#                Hospital Type              Hospital Ownership
# 0  Critical Access Hospitals  Voluntary non-profit - Private
# 1                Psychiatric                     Proprietary
# 2       Acute Care Hospitals  Voluntary non-profit - Private
# 3                Psychiatric                     Proprietary
# 4       Acute Care Hospitals                     Proprietary

# %%
hospital_reimbursement.head()
# Out:
#    Provider_Num                     Provider Name     Provider Street Address  \
# 0        839987  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        519118     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 2        733073    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET
# 3        201752          MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4        678488                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
#
#   Provider City Provider State  Provider Zip Code  Total Discharges  \
# 0        DOTHAN             AL              36301               118
# 1          BOAZ             AL              35957                43
# 2      FLORENCE             AL              35631                73
# 3           OPP             AL              36467                12
# 4    BIRMINGHAM             AL              35235                74
#
#    Average Covered Charges  Average Total Payments  Average Medicare Payments
# 0                 20855.61                 5026.19                    4115.52
# 1                 13289.09                 5413.63                    4490.93
# 2                 22261.60                 4922.18                    4021.79
# 3                 10901.33                 5343.50                    4284.17
# 4                 28117.95                 5947.12                    4819.53

# %%
## dataframe sizes

print("raw dataframe number of records:")
print("hospital_accounts:  {x}".format(x=hospital_accounts['Account_Num'].count()))
print("hospital_reimbursement:  {x}".format(x=hospital_reimbursement['Provider_Num'].count()))
# Out:
# raw dataframe number of records:
# hospital_accounts:  5339
# hospital_reimbursement:  2697

# %% [markdown]
# ### first we just explore the data and then try exact joins

# %% [markdown]
# #### focus on "Facility Name" and "Provider Name"
#  just pick providers starting with 'A' from both, sort and pick top 20 to visually compare

# %%
cond = hospital_accounts['Facility Name'].str.startswith('AD')
hospital_accounts.loc[cond].sort_values(by=['Facility Name'], ascending=True)[['Facility Name', 'Address']].head(25)
# Out:
#                                       Facility Name  \
# 3282                          AD HOSPITAL EAST, LLC
# 736   ADAIR ACUTE CARE AT OSAWATOMIE STATE HOSPITAL
# 2515                 ADAIR COUNTY MEMORIAL HOSPITAL
# 3915           ADAMS COUNTY REGIONAL MEDICAL CENTER
# 280                         ADAMS MEMORIAL HOSPITAL
# 3017               ADCARE HOSPITAL OF WORCESTER INC
# 2883                      ADENA PIKE MEDICAL CENTER
# 4211                  ADENA REGIONAL MEDICAL CENTER
# 4887       ADIRONDACK MEDICAL CENTER - SARANAC LAKE
# 4429         ADMIN DE SERVICIOS MEDICOS  PUERTO RIC
# 593                      ADVANCED SURGICAL HOSPITAL
# 4147                       ADVENTHEALTH CARROLLWOOD
# 71                       ADVENTHEALTH CENTRAL TEXAS
# 1362                         ADVENTHEALTH DADE CITY
# 2751                     ADVENTHEALTH DAYTONA BEACH
# 5035                            ADVENTHEALTH DELAND
# 4963                            ADVENTHEALTH DURAND
# 1692                     ADVENTHEALTH FISH MEMORIAL
# 2894                            ADVENTHEALTH GORDON
# 4536                  ADVENTHEALTH HEART OF FLORIDA
# 24                          ADVENTHEALTH LAKE WALES
# 5135                        ADVENTHEALTH MANCHESTER
# 1763                            ADVENTHEALTH MURRAY
# 556                   ADVENTHEALTH NEW SMYRNA BEACH
# 865                     ADVENTHEALTH NORTH PINELLAS
#
#                                        Address
# 3282             12950 EAST FREEWAY, SUITE 100
# 736                   500 STATE HOSPITAL DRIVE
# 2515                               609 SE KENT
# 3915                  230 MEDICAL CENTER DRIVE
# 280                            1100 MERCER AVE
# 3017                        107 LINCOLN STREET
# 2883                             100 DAWN LANE
# 4211                         272 HOSPITAL ROAD
# 4887           2233 STATE ROUTE 86, PO BOX 471
# 4429                  BO MONACILLO CARR NUM 22
# 593                            100 TRICH DRIVE
# 4147                     7171 N DALE MABRY HWY
# 71                     2201 S CLEAR CREEK ROAD
# 1362                          13100 FT KING RD
# 2751              301 MEMORIAL MEDICAL PARKWAY
# 5035                        701 W PLYMOUTH AVE
# 4963                            1220 3RD AVE W
# 1692                           1055 SAXON BLVD
# 2894                         1035 RED BUD ROAD
# 4536                              40100 HWY 27
# 24                               410 S 11TH ST
# 5135                   210 MARIE LANGDON DRIVE
# 1763  707 OLD DALTON ELLIJAY ROAD, PO BOX 1406
# 556                            401 PALMETTO ST
# 865                        1395 S PINELLAS AVE

# %%
cond = hospital_reimbursement['Provider Name'].str.startswith('AD')
hospital_reimbursement.sort_values(by=['Provider Name'], ascending=True)[['Provider Name','Provider Street Address', 'Provider City']].head(25)
# Out:
#                                           Provider Name  \
# 1051                         ABBEVILLE GENERAL HOSPITAL
# 1306                       ABBOTT NORTHWESTERN HOSPITAL
# 2376                    ABILENE REGIONAL MEDICAL CENTER
# 2109                         ABINGTON MEMORIAL HOSPITAL
# 99                              ABRAZO ARROWHEAD CAMPUS
# 91                             ABRAZO SCOTTSDALE CAMPUS
# 103                                  ABRAZO WEST CAMPUS
# 1056                            ACADIA GENERAL HOSPITAL
# 2080                                      ACMH HOSPITAL
# 1883                      ADENA REGIONAL MEDICAL CENTER
# 1613                          ADIRONDACK MEDICAL CENTER
# 841                      ADVENTIST BOLINGBROOK HOSPITAL
# 840                                  ADVENTIST GLENOAKS
# 1150    ADVENTIST HEALTHCARE SHADY GROVE MEDICAL CENTER
# 1124  ADVENTIST HEALTHCARE WASHINGTON ADVENTIST HOSP...
# 774                         ADVENTIST HINSDALE HOSPITAL
# 752               ADVENTIST LA GRANGE MEMORIAL HOSPITAL
# 204                            ADVENTIST MEDICAL CENTER
# 1985                           ADVENTIST MEDICAL CENTER
# 777                     ADVOCATE BROMENN MEDICAL CENTER
# 812           ADVOCATE CHRIST HOSPITAL & MEDICAL CENTER
# 810                     ADVOCATE CONDELL MEDICAL CENTER
# 836                    ADVOCATE GOOD SAMARITAN HOSPITAL
# 839                     ADVOCATE GOOD SHEPHERD HOSPITAL
# 802            ADVOCATE ILLINOIS MASONIC MEDICAL CENTER
#
#          Provider Street Address     Provider City
# 1051           118 N HOSPITAL DR         ABBEVILLE
# 1306        800 EAST 28TH STREET       MINNEAPOLIS
# 2376              6250 HWY 83/84           ABILENE
# 2109          1200 OLD YORK ROAD          ABINGTON
# 99       18701 NORTH 67TH AVENUE          GLENDALE
# 91           3929 EAST BELL ROAD           PHOENIX
# 103     13677 WEST MCDOWELL ROAD          GOODYEAR
# 1056  1305 CROWLEY RAYNE HIGHWAY           CROWLEY
# 2080             ONE NOLTE DRIVE        KITTANNING
# 1883           272 HOSPITAL ROAD       CHILLICOTHE
# 1613         2233 STATE ROUTE 86      SARANAC LAKE
# 841      500 REMINGTON BOULEVARD       BOLINGBROOK
# 840          701 WINTHROP AVENUE  GLENDALE HEIGHTS
# 1150   9901 MEDICAL CENTER DRIVE         ROCKVILLE
# 1124         7600 CARROLL AVENUE       TAKOMA PARK
# 774             120 NORTH OAK ST          HINSDALE
# 752     5101 S WILLOW SPRINGS RD         LA GRANGE
# 204               115 MALL DRIVE           HANFORD
# 1985      10123 SE MARKET STREET          PORTLAND
# 777         1304 FRANKLIN AVENUE            NORMAL
# 812           4440 W 95TH STREET          OAK LAWN
# 810          801 S MILWAUKEE AVE      LIBERTYVILLE
# 836         3815 HIGHLAND AVENUE     DOWNERS GROVE
# 839          450 WEST HIGHWAY 22        BARRINGTON
# 802   836 WEST WELLINGTON AVENUE           CHICAGO

# %% [markdown]
# ### try first a straight left outer join on the name
#
# see https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
merged = hospital_accounts.merge(hospital_reimbursement, left_on = 'Facility Name', right_on='Provider Name',  how='left')

## show the records where on the left we have the AD hospitals
cond = merged['Facility Name'].str.startswith('AD')
merged[cond][['Facility Name', 'Provider Name']].sort_values(by='Facility Name').head(20)
# Out:
#                                       Facility Name  \
# 3519                          AD HOSPITAL EAST, LLC
# 784   ADAIR ACUTE CARE AT OSAWATOMIE STATE HOSPITAL
# 2704                 ADAIR COUNTY MEMORIAL HOSPITAL
# 4213           ADAMS COUNTY REGIONAL MEDICAL CENTER
# 307                         ADAMS MEMORIAL HOSPITAL
# 3246               ADCARE HOSPITAL OF WORCESTER INC
# 3102                      ADENA PIKE MEDICAL CENTER
# 4527                  ADENA REGIONAL MEDICAL CENTER
# 5245       ADIRONDACK MEDICAL CENTER - SARANAC LAKE
# 4764         ADMIN DE SERVICIOS MEDICOS  PUERTO RIC
# 639                      ADVANCED SURGICAL HOSPITAL
# 4463                       ADVENTHEALTH CARROLLWOOD
# 79                       ADVENTHEALTH CENTRAL TEXAS
# 1434                         ADVENTHEALTH DADE CITY
# 2966                     ADVENTHEALTH DAYTONA BEACH
# 5413                            ADVENTHEALTH DELAND
# 5324                            ADVENTHEALTH DURAND
# 1776                     ADVENTHEALTH FISH MEMORIAL
# 3113                            ADVENTHEALTH GORDON
# 4873                  ADVENTHEALTH HEART OF FLORIDA
#
#                       Provider Name
# 3519                            NaN
# 784                             NaN
# 2704                            NaN
# 4213                            NaN
# 307                             NaN
# 3246                            NaN
# 3102                            NaN
# 4527  ADENA REGIONAL MEDICAL CENTER
# 5245                            NaN
# 4764                            NaN
# 639                             NaN
# 4463                            NaN
# 79                              NaN
# 1434                            NaN
# 2966                            NaN
# 5413                            NaN
# 5324                            NaN
# 1776                            NaN
# 3113                            NaN
# 4873                            NaN

# %%
## how many have we matched?
merged[merged['Provider Name'].notnull()]['Provider Name'].count()
# Out:
# 2739

# %% [markdown]
# ### how about a full outer join?

# %%
merged = hospital_accounts.merge(hospital_reimbursement, left_on = 'Facility Name', right_on='Provider Name',  how='outer')

## show the records where on the left we have the AD hospitals
cond1 = (merged['Facility Name'].notnull()) 
cond2 = (merged['Facility Name'].str.startswith('AD'))
merged[cond1 & cond2][['Facility Name', 'Provider Name']].sort_values(by='Facility Name').head(20)
# Out:
#                                       Facility Name  \
# 3757                          AD HOSPITAL EAST, LLC
# 1029  ADAIR ACUTE CARE AT OSAWATOMIE STATE HOSPITAL
# 2971                 ADAIR COUNTY MEMORIAL HOSPITAL
# 4367           ADAMS COUNTY REGIONAL MEDICAL CENTER
# 438                         ADAMS MEMORIAL HOSPITAL
# 3500               ADCARE HOSPITAL OF WORCESTER INC
# 3370                      ADENA PIKE MEDICAL CENTER
# 4652                  ADENA REGIONAL MEDICAL CENTER
# 5301       ADIRONDACK MEDICAL CENTER - SARANAC LAKE
# 4862         ADMIN DE SERVICIOS MEDICOS  PUERTO RIC
# 877                      ADVANCED SURGICAL HOSPITAL
# 4589                       ADVENTHEALTH CARROLLWOOD
# 123                      ADVENTHEALTH CENTRAL TEXAS
# 1688                         ADVENTHEALTH DADE CITY
# 3234                     ADVENTHEALTH DAYTONA BEACH
# 5443                            ADVENTHEALTH DELAND
# 5375                            ADVENTHEALTH DURAND
# 2050                     ADVENTHEALTH FISH MEMORIAL
# 3381                            ADVENTHEALTH GORDON
# 4966                  ADVENTHEALTH HEART OF FLORIDA
#
#                       Provider Name
# 3757                            NaN
# 1029                            NaN
# 2971                            NaN
# 4367                            NaN
# 438                             NaN
# 3500                            NaN
# 3370                            NaN
# 4652  ADENA REGIONAL MEDICAL CENTER
# 5301                            NaN
# 4862                            NaN
# 877                             NaN
# 4589                            NaN
# 123                             NaN
# 1688                            NaN
# 3234                            NaN
# 5443                            NaN
# 5375                            NaN
# 2050                            NaN
# 3381                            NaN
# 4966                            NaN

# %% [markdown]
# ## Example using fuzzymatcher

# %%
import fuzzymatcher

# %%
# Columns to match on from df_left
left_on = ["Facility Name", "Address", "City", "State"]

# Columns to match on from df_right
right_on = [    "Provider Name",  "Provider Street Address", "Provider City",    "Provider State"]

# %%
## try link_table first
linked = fuzzymatcher.link_table(hospital_accounts,
                                               hospital_reimbursement,
                                               left_on,
                                               right_on,
                                               left_id_col='Account_Num',
                                               right_id_col='Provider_Num')

# %%
linked.head()
# Out:
#    __id_left  __id_right  match_score  match_rank           Facility Name  \
# 0      10605    741329.0    -0.024854           1  SAGE MEMORIAL HOSPITAL
# 1      10605    730311.0    -0.074309           2  SAGE MEMORIAL HOSPITAL
# 2      10605    657875.0    -0.077214           3  SAGE MEMORIAL HOSPITAL
# 3      10605    299065.0    -0.085724           4  SAGE MEMORIAL HOSPITAL
# 4      10605    895820.0    -0.085724           5  SAGE MEMORIAL HOSPITAL
#
#                   Provider Name
# 0    MEMORIAL REGIONAL HOSPITAL
# 1     JACKSON MEMORIAL HOSPITAL
# 2     JOHNSON MEMORIAL HOSPITAL
# 3  HUNTINGTON MEMORIAL HOSPITAL
# 4  LAWRENCE & MEMORIAL HOSPITAL

# %%
linked[linked['Facility Name'].str.contains('GORDON')].sort_values(by='match_score', ascending=False)
# Out:
#        __id_left  __id_right  match_score  match_rank  \
# 83533      24125    515652.0     0.117880           1
# 83381      24261    726996.0     0.100981           1
# 83382      24261    741329.0    -0.128907           2
# 83383      24261    730311.0    -0.178362           3
# 83384      24261    657875.0    -0.181267           4
# 83385      24261    299065.0    -0.189776           5
# 83386      24261    895820.0    -0.189776           6
# 83387      24261    308278.0    -0.193006           7
# 83392      24261    220714.0    -0.203041          12
# 83393      24261    558189.0    -0.203041          13
# 83391      24261    811865.0    -0.203041          11
# 83390      24261    522917.0    -0.203041          10
# 83389      24261    824535.0    -0.203041           9
# 83388      24261    700618.0    -0.203041           8
# 83401      24261    163516.0    -0.213075          21
# 83405      24261    237754.0    -0.213075          25
# 83404      24261    891017.0    -0.213075          24
# 83403      24261    523073.0    -0.213075          23
# 83402      24261    489749.0    -0.213075          22
# 83406      24261    578048.0    -0.213075          26
# 83400      24261    214254.0    -0.213075          20
# 83399      24261    340833.0    -0.213075          19
# 83398      24261    254598.0    -0.213075          18
# 83397      24261    589667.0    -0.213075          17
# 83396      24261    583613.0    -0.213075          16
# 83395      24261    693188.0    -0.213075          15
# 83394      24261    201752.0    -0.213075          14
# 83407      24261    828778.0    -0.237840          27
# 83408      24261    894631.0    -0.241403          28
# 83409      24261    344869.0    -0.260076          29
# 83410      24261    119186.0    -0.284028          30
# 83411      24261    754768.0    -0.289352          31
# 83412      24261    654802.0    -0.291991          32
# 83413      24261    163388.0    -0.291991          33
# 83414      24261    618303.0    -0.303024          34
# 83415      24261    268034.0    -0.303730          35
# 83416      24261    607217.0    -0.306083          36
# 83417      24261    190089.0    -0.307895          37
# 83418      24261    213667.0    -0.321160          38
# 83419      24261    590671.0    -0.327029          39
# 83420      24261    124586.0    -0.327029          40
# 83421      24261    733073.0    -0.337064          41
# 83422      24261    227327.0    -0.347098          42
# 83423      24261    329514.0    -0.347098          43
# 83424      24261    315986.0    -0.370094          44
# 83425      24261    133329.0    -0.406944          45
# 83426      24261    403151.0    -0.427187          46
# 83427      24261    140742.0    -0.435114          47
# 83428      24261    343862.0    -0.435114          48
# 83429      24261    151114.0    -0.445149          49
# 83430      24261    133210.0    -0.455183          50
#
#                            Facility Name  \
# 83533                ADVENTHEALTH GORDON
# 83381  GORDON MEMORIAL HOSPITAL DISTRICT
# 83382  GORDON MEMORIAL HOSPITAL DISTRICT
# 83383  GORDON MEMORIAL HOSPITAL DISTRICT
# 83384  GORDON MEMORIAL HOSPITAL DISTRICT
# 83385  GORDON MEMORIAL HOSPITAL DISTRICT
# 83386  GORDON MEMORIAL HOSPITAL DISTRICT
# 83387  GORDON MEMORIAL HOSPITAL DISTRICT
# 83392  GORDON MEMORIAL HOSPITAL DISTRICT
# 83393  GORDON MEMORIAL HOSPITAL DISTRICT
# 83391  GORDON MEMORIAL HOSPITAL DISTRICT
# 83390  GORDON MEMORIAL HOSPITAL DISTRICT
# 83389  GORDON MEMORIAL HOSPITAL DISTRICT
# 83388  GORDON MEMORIAL HOSPITAL DISTRICT
# 83401  GORDON MEMORIAL HOSPITAL DISTRICT
# 83405  GORDON MEMORIAL HOSPITAL DISTRICT
# 83404  GORDON MEMORIAL HOSPITAL DISTRICT
# 83403  GORDON MEMORIAL HOSPITAL DISTRICT
# 83402  GORDON MEMORIAL HOSPITAL DISTRICT
# 83406  GORDON MEMORIAL HOSPITAL DISTRICT
# 83400  GORDON MEMORIAL HOSPITAL DISTRICT
# 83399  GORDON MEMORIAL HOSPITAL DISTRICT
# 83398  GORDON MEMORIAL HOSPITAL DISTRICT
# 83397  GORDON MEMORIAL HOSPITAL DISTRICT
# 83396  GORDON MEMORIAL HOSPITAL DISTRICT
# 83395  GORDON MEMORIAL HOSPITAL DISTRICT
# 83394  GORDON MEMORIAL HOSPITAL DISTRICT
# 83407  GORDON MEMORIAL HOSPITAL DISTRICT
# 83408  GORDON MEMORIAL HOSPITAL DISTRICT
# 83409  GORDON MEMORIAL HOSPITAL DISTRICT
# 83410  GORDON MEMORIAL HOSPITAL DISTRICT
# 83411  GORDON MEMORIAL HOSPITAL DISTRICT
# 83412  GORDON MEMORIAL HOSPITAL DISTRICT
# 83413  GORDON MEMORIAL HOSPITAL DISTRICT
# 83414  GORDON MEMORIAL HOSPITAL DISTRICT
# 83415  GORDON MEMORIAL HOSPITAL DISTRICT
# 83416  GORDON MEMORIAL HOSPITAL DISTRICT
# 83417  GORDON MEMORIAL HOSPITAL DISTRICT
# 83418  GORDON MEMORIAL HOSPITAL DISTRICT
# 83419  GORDON MEMORIAL HOSPITAL DISTRICT
# 83420  GORDON MEMORIAL HOSPITAL DISTRICT
# 83421  GORDON MEMORIAL HOSPITAL DISTRICT
# 83422  GORDON MEMORIAL HOSPITAL DISTRICT
# 83423  GORDON MEMORIAL HOSPITAL DISTRICT
# 83424  GORDON MEMORIAL HOSPITAL DISTRICT
# 83425  GORDON MEMORIAL HOSPITAL DISTRICT
# 83426  GORDON MEMORIAL HOSPITAL DISTRICT
# 83427  GORDON MEMORIAL HOSPITAL DISTRICT
# 83428  GORDON MEMORIAL HOSPITAL DISTRICT
# 83429  GORDON MEMORIAL HOSPITAL DISTRICT
# 83430  GORDON MEMORIAL HOSPITAL DISTRICT
#
#                                           Provider Name
# 83533                                   GORDON HOSPITAL
# 83381                      MEMORIAL HOSPITAL OF GARDENA
# 83382                        MEMORIAL REGIONAL HOSPITAL
# 83383                         JACKSON MEMORIAL HOSPITAL
# 83384                         JOHNSON MEMORIAL HOSPITAL
# 83385                      HUNTINGTON MEMORIAL HOSPITAL
# 83386                      LAWRENCE & MEMORIAL HOSPITAL
# 83387                             LEE MEMORIAL HOSPITAL
# 83392                        WOODLAND MEMORIAL HOSPITAL
# 83393                          CITRUS MEMORIAL HOSPITAL
# 83391                           SHARP MEMORIAL HOSPITAL
# 83390                     BAKERSFIELD MEMORIAL HOSPITAL
# 83389                       FAIRBANKS MEMORIAL HOSPITAL
# 83388                      SPRINGHILL MEMORIAL HOSPITAL
# 83401                          BARTON MEMORIAL HOSPITAL
# 83405                          SIBLEY MEMORIAL HOSPITAL
# 83404                       NANTICOKE MEMORIAL HOSPITAL
# 83403                      MANCHESTER MEMORIAL HOSPITAL
# 83402                        MONTROSE MEMORIAL HOSPITAL
# 83406                         MANATEE MEMORIAL HOSPITAL
# 83400                            LODI MEMORIAL HOSPITAL
# 83399                         RIDEOUT MEMORIAL HOSPITAL
# 83398                          SALINE MEMORIAL HOSPITAL
# 83397                            DREW MEMORIAL HOSPITAL
# 83396                        CHAMBERS MEMORIAL HOSPITAL
# 83395                    STRINGFELLOW MEMORIAL HOSPITAL
# 83394                          MIZELL MEMORIAL HOSPITAL
# 83407          FLORIDA HOSPITAL MEMORIAL MEDICAL CENTER
# 83408                   SAINT FRANCIS MEMORIAL HOSPITAL
# 83409                    DELTA COUNTY MEMORIAL HOSPITAL
# 83410                  SALINAS VALLEY MEMORIAL HOSPITAL
# 83411                      GROVE HILL MEMORIAL HOSPITAL
# 83412                     NEA BAPTIST MEMORIAL HOSPITAL
# 83413                      SANTA ROSA MEMORIAL HOSPITAL
# 83414                    SAN GORGONIO MEMORIAL HOSPITAL
# 83415               HOAG MEMORIAL HOSPITAL PRESBYTERIAN
# 83416                    FLORIDA HOSPITAL FISH MEMORIAL
# 83417                   SIERRA NEVADA MEMORIAL HOSPITAL
# 83418             BAYHEALTH - MILFORD MEMORIAL HOSPITAL
# 83419             SCRIPPS MEMORIAL HOSPITAL - ENCINITAS
# 83420                       MEMORIAL HOSPITAL LOS BANOS
# 83421                    ELIZA COFFEE MEMORIAL HOSPITAL
# 83422                    HELEN KELLER MEMORIAL HOSPITAL
# 83423                   HAZEL HAWKINS MEMORIAL HOSPITAL
# 83424      COMMUNITY MEMORIAL HOSPITAL SAN BUENAVENTURA
# 83425                  JOHN F KENNEDY MEMORIAL HOSPITAL
# 83426  UNIVERSITY COLO HEALTH MEMORIAL HOSPITAL CENTRAL
# 83427                    D W MCMILLAN MEMORIAL HOSPITAL
# 83428                SCRIPPS MEMORIAL HOSPITAL LA JOLLA
# 83429              BRYAN W. WHITFIELD MEMORIAL HOSPITAL
# 83430                     L V STABLER MEMORIAL HOSPITAL

# %%
# Now perform the match
# It will take several minutes to run on this data set
matched_results = fuzzymatcher.fuzzy_left_join(hospital_accounts,
                                               hospital_reimbursement,
                                               left_on,
                                               right_on,
                                               left_id_col='Account_Num',
                                               right_id_col='Provider_Num')

# %%
matched_results[["Facility Name", "Provider Name"]].head()
# Out:
#                          Facility Name                      Provider Name
# 0               SAGE MEMORIAL HOSPITAL            TYLER MEMORIAL HOSPITAL
# 234        WOODRIDGE BEHAVIORAL CENTER            CRISP REGIONAL HOSPITAL
# 446           DOUGLAS GARDENS HOSPITAL          JACKSON MEMORIAL HOSPITAL
# 675  SUNCOAST BEHAVIORAL HEALTH CENTER               BLAKE MEDICAL CENTER
# 893           TREASURE VALLEY HOSPITAL  ST LUKE'S REGIONAL MEDICAL CENTER

# %%
# Reorder the columns to make viewing easier
cols = [
    "best_match_score", "Facility Name", "Provider Name", "Address", "Provider Street Address",
    "Provider City", "City", "Provider State", "State"
]

# %%
# Let's see the best matches
matched_results[cols].sort_values(by=['best_match_score'], ascending=False).head(5)
# Out:
#         best_match_score                                      Facility Name  \
# 77995           3.090931    RARITAN BAY MEDICAL CENTER PERTH AMBOY DIVISION
# 532606          2.799072            ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL
# 78605           2.785132  AVERA MCKENNAN HOSPITAL & UNIVERSITY HEALTH CE...
# 242528          2.778860  JOHN T MATHER MEMORIAL HOSPITAL  OF PORT JEFFE...
# 447173          2.721425               MAYO CLINIC HEALTH SYSTEM - RED WING
#
#                                             Provider Name  \
# 77995     RARITAN BAY MEDICAL CENTER PERTH AMBOY DIVISION
# 532606            ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL
# 78605   AVERA MCKENNAN HOSPITAL & UNIVERSITY HEALTH CE...
# 242528  JOHN T MATHER MEMORIAL HOSPITAL  OF PORT JEFFE...
# 447173              MAYO CLINIC HEALTH SYSTEM IN RED WING
#
#                                        Address  \
# 77995                    530 NEW BRUNSWICK AVE
# 532606           ONE ROBERT WOOD JOHNSON PLACE
# 78605   1325 S CLIFF AVE  POST OFFICE BOX 5045
# 242528                   75 NORTH COUNTRY ROAD
# 447173         701 HEWITT BOULEVARD, PO BOX 95
#
#                        Provider Street Address   Provider City  \
# 77995                    530 NEW BRUNSWICK AVE     PERTH AMBOY
# 532606           ONE ROBERT WOOD JOHNSON PLACE   NEW BRUNSWICK
# 78605   1325 S CLIFF AVE  POST OFFICE BOX 5045     SIOUX FALLS
# 242528                   75 NORTH COUNTRY ROAD  PORT JEFFERSON
# 447173         701 HEWITT BOULEVARD, PO BOX 95        RED WING
#
#                   City Provider State State
# 77995      PERTH AMBOY             NJ    NJ
# 532606   NEW BRUNSWICK             NJ    NJ
# 78605      SIOUX FALLS             SD    SD
# 242528  PORT JEFFERSON             NY    NY
# 447173        RED WING             MN    MN

# %%
# Now the worst matches
matched_results[cols].sort_values(by=['best_match_score'],
                                  ascending=True).head(5)
# Out:
#         best_match_score                                      Facility Name  \
# 427229         -2.268231                      CENTRO MEDICO WILMA N VAZQUEZ
# 83304          -2.124071  DOCTOR CENTER HOSPITAL SAN FERNANDO DE LA CARO...
# 42761          -2.106746     HOSPITAL ONCOLOGICO DR ISAAC GONZALEZ MARTINEZ
# 451126         -2.050888           CENTRO DE SALUD CONDUCTUAL MENONITA-CIMA
# 477033         -1.996508             ADMIN DE SERVICIOS MEDICOS  PUERTO RIC
#
#                            Provider Name  \
# 427229       BAPTIST MEDICAL CENTER EAST
# 83304   OVERLAKE HOSPITAL MEDICAL CENTER
# 42761             SCRIPPS MERCY HOSPITAL
# 451126   MILFORD REGIONAL MEDICAL CENTER
# 477033              MAINE MEDICAL CENTER
#
#                                                   Address  \
# 427229      CARR. 2 KM 39.5    ROAD NUMBER 2 BO ALGARROBO
# 83304   EDIF JESUS T PINEIRO AVE FERNANDEZ JUNCOS BO P...
# 42761   BO. MONACILLOS CARR 22 CENTRO MEDICO DE PUERTO...
# 451126  CARR ESTATAL 14 INTERIOR SARGENTO GERARDO SANT...
# 477033                           BO MONACILLO CARR NUM 22
#
#        Provider Street Address Provider City       City Provider State State
# 427229         400 TAYLOR ROAD    MONTGOMERY  VEGA BAJA             AL    PR
# 83304        1035-116TH AVE NE      BELLEVUE   CAROLINA             WA    PR
# 42761             4077 5TH AVE     SAN DIEGO   SAN JUAN             CA    PR
# 451126      14 PROSPECT STREET       MILFORD   AIBONITO             MA    PR
# 477033          22 BRAMHALL ST      PORTLAND   SAN JUAN             ME    PR

# %%
# Look at the matches around 1
matched_results[cols].sort_values(
    by=['best_match_score'], ascending=False).head(10)
# Out:
#         best_match_score             Facility Name  \
# 414728          0.999843     PRISMA HEALTH BAPTIST
# 148944          0.999724           CHRIST HOSPITAL
# 388721          0.997759   RUSSELL COUNTY HOSPITAL
# 378541          0.993306  SKY RIDGE MEDICAL CENTER
# 304062          0.991168         HIGHLAND HOSPITAL
# 539270          0.990481            PAOLI HOSPITAL
# 251923          0.986695     NYU WINTHROP HOSPITAL
# 311394          0.986440       ADVENTHEALTH GORDON
# 204356          0.985763   MEMORIAL MEDICAL CENTER
# 102416          0.984978   HENDRICK MEDICAL CENTER
#
#                         Provider Name                    Address  \
# 414728        PALMETTO HEALTH BAPTIST   1330 TAYLOR AT MARION ST
# 148944                CHRIST HOSPITAL         2139 AUBURN AVENUE
# 388721  RUSSELL COUNTY MEDICAL CENTER          58 CARROLL STREET
# 378541       SKY RIDGE MEDICAL CENTER    10101 RIDGEGATE PARKWAY
# 304062              HIGHLAND HOSPITAL          1000 SOUTH AVENUE
# 539270       MAIN LINE HOSPITAL PAOLI  255 WEST LANCASTER AVENUE
# 251923   WINTHROP-UNIVERSITY HOSPITAL           259 FIRST STREET
# 311394                GORDON HOSPITAL          1035 RED BUD ROAD
# 204356        MEMORIAL MEDICAL CENTER             701 N FIRST ST
# 102416        HENDRICK MEDICAL CENTER                  1900 PINE
#
#           Provider Street Address Provider City         City Provider State  \
# 414728        TAYLOR AT MARION ST      COLUMBIA     COLUMBIA             SC
# 148944         2139 AUBURN AVENUE    CINCINNATI   CINCINNATI             OH
# 388721          58 CARROLL STREET       LEBANON      LEBANON             VA
# 378541   10101 RIDGE GATE PARKWAY     LONE TREE    LONE TREE             CO
# 304062          1000 SOUTH AVENUE     ROCHESTER    ROCHESTER             NY
# 539270  255 WEST LANCASTER AVENUE         PAOLI        PAOLI             PA
# 251923           259 FIRST STREET       MINEOLA      MINEOLA             NY
# 311394          1035 RED BUD ROAD       CALHOUN      CALHOUN             GA
# 204356             701 N FIRST ST   SPRINGFIELD  SPRINGFIELD             IL
# 102416                  1900 PINE       ABILENE      ABILENE             TX
#
#        State
# 414728    SC
# 148944    OH
# 388721    VA
# 378541    CO
# 304062    NY
# 539270    PA
# 251923    NY
# 311394    GA
# 204356    IL
# 102416    TX

# %%
matched_results[cols].query("best_match_score <= .6").sort_values(
    by=['best_match_score'], ascending=False).head(5)
# Out:
#         best_match_score                                 Facility Name  \
# 9976            0.594255                    ADVENTHEALTH CENTRAL TEXAS
# 158487          0.585892      HOUSTON METHODIST THE WOODLANDS HOSPITAL
# 489328          0.576772             MUSC HEALTH MARION MEDICAL CENTER
# 466350          0.575092                  MERCY HEALTH-LORAIN HOSPITAL
# 377734          0.566592  UT HEALTH EAST TEXAS TYLER REGIONAL HOSPITAL
#
#                            Provider Name                    Address  \
# 9976                  METROPLEX HOSPITAL    2201 S CLEAR CREEK ROAD
# 158487  ST LUKE'S THE WOODLANDS HOSPITAL  17201 INTERSTATE 45 SOUTH
# 489328  CAROLINAS HOSPITAL SYSTEM MARION              2829 E HWY 76
# 466350     MERCY REGIONAL MEDICAL CENTER            3700 KOLBE ROAD
# 377734         EAST TEXAS MEDICAL CENTER     1000 SOUTH BECKHAM AVE
#
#           Provider Street Address  Provider City           City  \
# 9976      2201 S CLEAR CREEK ROAD        KILLEEN        KILLEEN
# 158487        17200 ST LUKE'S WAY  THE WOODLANDS  THE WOODLANDS
# 489328              2829 E HWY 76        MULLINS        MULLINS
# 466350            3700 KOLBE ROAD         LORAIN         LORAIN
# 377734  1000 SOUTH BECKHAM STREET          TYLER          TYLER
#
#        Provider State State
# 9976               TX    TX
# 158487             TX    TX
# 489328             SC    SC
# 466350             OH    OH
# 377734             TX    TX

# %% [markdown]
# ## Example using Splink

# %%
from splink.duckdb.duckdb_linker import DuckDBLinker
from splink.duckdb.duckdb_comparison_library import (
    exact_match,
    levenshtein_at_thresholds,
)

# %%
hospital_dupes = pd.read_csv(
    'https://github.com/chris1610/pbpython/raw/master/data/hospital_account_dupes.csv',
    index_col='Account_Num')

# %%
settings = {
    "link_type": "dedupe_only",
    "comparisons": [
        levenshtein_at_thresholds("Facility Name", 2)
    ],
}

# %%
linker = DuckDBLinker(hospital_dupes, settings)

# %%
pairwise_predictions = linker.predict()
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# <ipython-input-26-725f2be7eb35> in <module>
# ----> 1 pairwise_predictions = linker.predict()
#
# /usr/local/lib/python3.7/dist-packages/splink/linker.py in predict(self, threshold_match_probability, threshold_match_weight)
#    1014             self._enqueue_sql(sql["sql"], sql["output_table_name"])
#    1015
# -> 1016         predictions = self._execute_sql_pipeline(input_dataframes)
#    1017         self._predict_warning()
#    1018         return predictions
#
# /usr/local/lib/python3.7/dist-packages/splink/linker.py in _execute_sql_pipeline(self, input_dataframes, materialise_as_hash, use_cache)
#     348                     output_tablename_templated,
#     349                     materialise_as_hash,
# --> 350                     use_cache,
#     351                 )
#     352             except Error as e:
#
# /usr/local/lib/python3.7/dist-packages/splink/linker.py in _sql_to_splink_dataframe_checking_cache(self, sql, output_tablename_templated, materialise_as_hash, use_cache)
#     422         if materialise_as_hash:
#     423             splink_dataframe = self._execute_sql_against_backend(
# --> 424                 sql, output_tablename_templated, table_name_hash
#     425             )
#     426         else:
#
# /usr/local/lib/python3.7/dist-packages/splink/duckdb/duckdb_linker.py in _execute_sql_against_backend(self, sql, templated_name, physical_name)
#     184         ({sql})
#     185         """
# --> 186         self._con.execute(sql).fetch_df()
#     187
#     188         return DuckDBLinkerDataFrame(templated_name, physical_name, self)
#
# BinderException: Binder Error: Values list "l" does not have a column named "unique_id"

# %% [markdown]
# ## Example using Python Record Linkage Toolkit

# %%
import recordlinkage

# %% [markdown]
# ### first repeat the analysis we did using the fuzzyMatcher
# what additional parameters can we set?
# do we get different results?

# %%
# Build the indexer
indexer = recordlinkage.Index()
# Can use full or block
# indexer.full()
indexer.block(left_on='State', right_on='Provider State')

# Use sortedneighbor as a good option if data is not clean
# indexer.sortedneighbourhood(left_on='State', right_on='Provider State')

# %%
candidates = indexer.index(hospital_accounts, hospital_reimbursement)

# %%
# Let's see how many matches we want to do
print(len(candidates))
# Out:
# 475830

# %%
# Takes 3 minutes using the full index.
# 14s using sorted neighbor
# 7s using blocking
compare = recordlinkage.Compare()
compare.exact('City', 'Provider City', label='City')
compare.string('Facility Name',
               'Provider Name',
               threshold=0.85,
               label='Hosp_Name')
compare.string('Address',
               'Provider Street Address',
               method='jarowinkler',
               threshold=0.85,
               label='Hosp_Address')
features = compare.compute(candidates, hospital_accounts,
                           hospital_reimbursement)

# %%
features.describe()
# Out:
#                 City      Hosp_Name   Hosp_Address
# count  475830.000000  475830.000000  475830.000000
# mean        0.019372       0.005294       0.007431
# std         0.137830       0.072566       0.085884
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000

# %%
# What are the score totals?
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 3.0      2290
# 2.0       461
# 1.0      8261
# 0.0    987848
# dtype: int64

# %%
# Get the potential matches
potential_matches = features[features.sum(axis=1) > 1].reset_index()

# %%
potential_matches['Score'] = potential_matches.loc[:, 'City':'Hosp_Address'].sum(axis=1)
potential_matches.head()
# Out:
#    Account_Num  Provider_Num  City  Hosp_Name  Hosp_Address  Score
# 0        51216        268781     0        1.0           1.0    2.0
# 1        55272        556917     1        1.0           1.0    3.0
# 2        87807        854637     1        1.0           1.0    3.0
# 3        51151        783146     1        0.0           1.0    2.0
# 4        11740        260374     1        1.0           1.0    3.0

# %%
hospital_accounts.loc[51216,:]
# Out:
# Facility Name             ST FRANCIS MEDICAL CENTER
# Address                       2400 ST FRANCIS DRIVE
# City                                   BRECKENRIDGE
# State                                            MN
# ZIP Code                                      56520
# County Name                                  WILKIN
# Phone Number                         (218) 643-3000
# Hospital Type             Critical Access Hospitals
# Hospital Ownership    Voluntary non-profit - Church
# Name: 51216, dtype: object

# %%
hospital_reimbursement.loc[268781,:]
# Out:
# Provider Name                SAINT FRANCIS MEDICAL CENTER
# Provider Street Address                 211 ST FRANCIS DR
# Provider City                              CAPE GIRARDEAU
# Provider State                                         MO
# Provider Zip Code                                   63703
# Total Discharges                                      141
# Average Covered Charges                          42515.09
# Average Total Payments                            5902.24
# Average Medicare Payments                         4993.43
# Name: 268781, dtype: object

# %%
# Add some convenience columns for comparing data
hospital_accounts['Acct_Name_Lookup'] = hospital_accounts[[
    'Facility Name', 'Address', 'City', 'State'
]].apply(lambda x: '_'.join(x), axis=1)

# %%
hospital_reimbursement['Reimbursement_Name_Lookup'] = hospital_reimbursement[[
    'Provider Name', 'Provider Street Address', 'Provider City',
    'Provider State'
]].apply(lambda x: '_'.join(x), axis=1)

# %%
reimbursement_lookup = hospital_reimbursement[['Reimbursement_Name_Lookup']].reset_index()
account_lookup = hospital_accounts[['Acct_Name_Lookup']].reset_index()

# %%
account_lookup.head()
# Out:
#    Account_Num                                   Acct_Name_Lookup
# 0        10605  SAGE MEMORIAL HOSPITAL_STATE ROUTE 264 SOUTH 1...
# 1        24250  WOODRIDGE BEHAVIORAL CENTER_600 NORTH 7TH STRE...
# 2        10341  DOUGLAS GARDENS HOSPITAL_5200 NE 2ND AVE_MIAMI_FL
# 3        81101  SUNCOAST BEHAVIORAL HEALTH CENTER_4480 51ST ST...
# 4        39835  TREASURE VALLEY HOSPITAL_8800 WEST EMERALD STR...

# %%
reimbursement_lookup.head()
# Out:
#    Provider_Num                          Reimbursement_Name_Lookup
# 0        839987  SOUTHEAST ALABAMA MEDICAL CENTER_1108 ROSS CLA...
# 1        519118  MARSHALL MEDICAL CENTER SOUTH_2505 U S HIGHWAY...
# 2        733073  ELIZA COFFEE MEMORIAL HOSPITAL_205 MARENGO STR...
# 3        201752      MIZELL MEMORIAL HOSPITAL_702 N MAIN ST_OPP_AL
# 4        678488  ST VINCENT'S EAST_50 MEDICAL PARK EAST DRIVE_B...

# %%
account_merge = potential_matches.merge(account_lookup, how='left')

# %%
account_merge.head()
# Out:
#    Account_Num  Provider_Num  City  Hosp_Name  Hosp_Address  Score  \
# 0        51216        268781     0        1.0           1.0    2.0
# 1        55272        556917     1        1.0           1.0    3.0
# 2        87807        854637     1        1.0           1.0    3.0
# 3        51151        783146     1        0.0           1.0    2.0
# 4        11740        260374     1        1.0           1.0    3.0
#
#                                     Acct_Name_Lookup
# 0  ST FRANCIS MEDICAL CENTER_2400 ST FRANCIS DRIV...
# 1  SCOTTSDALE OSBORN MEDICAL CENTER_7400 EAST OSB...
# 2  ORO VALLEY HOSPITAL_1551 EAST TANGERINE ROAD_O...
# 3  ST. LUKE'S BEHAVIORAL HOSPITAL, LP_1800 EAST V...
# 4  SUMMIT HEALTHCARE REGIONAL MEDICAL CENTER_2200...

# %%
reimbursement_lookup.head()
# Out:
#    Provider_Num                          Reimbursement_Name_Lookup
# 0        839987  SOUTHEAST ALABAMA MEDICAL CENTER_1108 ROSS CLA...
# 1        519118  MARSHALL MEDICAL CENTER SOUTH_2505 U S HIGHWAY...
# 2        733073  ELIZA COFFEE MEMORIAL HOSPITAL_205 MARENGO STR...
# 3        201752      MIZELL MEMORIAL HOSPITAL_702 N MAIN ST_OPP_AL
# 4        678488  ST VINCENT'S EAST_50 MEDICAL PARK EAST DRIVE_B...

# %%
# Let's build a dataframe to  compare
final_merge = account_merge.merge(reimbursement_lookup, how='left')

# %%
cols = [
    'Account_Num', 'Provider_Num', 'Score', 'Acct_Name_Lookup',
    'Reimbursement_Name_Lookup'
]

# %%
final_merge[cols].sort_values(by=['Account_Num', 'Score'], ascending=False)
# Out:
#       Account_Num  Provider_Num  Score  \
# 2675        94995        825914    3.0
# 1987        94953        819181    3.0
# 1045        94943        680596    3.0
# 2319        94923        403151    3.0
# 2526        94887        752284    2.0
# ...           ...           ...    ...
# 2093        10165        188247    3.0
# 1836        10090        212069    3.0
# 2438        10043        140535    3.0
# 1971        10020        210657    3.0
# 1970        10020        121670    2.0
#
#                                        Acct_Name_Lookup  \
# 2675  CLAIBORNE MEDICAL CENTER_1850 OLD KNOXVILLE HI...
# 1987  LAKE CHARLES MEMORIAL HOSPITAL_1701 OAK PARK B...
# 1045  VALLEY PRESBYTERIAN HOSPITAL_15107 VANOWEN ST_...
# 2319  UNIVERSITY COLO HEALTH MEMORIAL HOSPITAL CENTR...
# 2526  NEW YORK-PRESBYTERIAN BROOKLYN METHODIST HOSPI...
# ...                                                 ...
# 2093  UTAH VALLEY HOSPITAL_1034 NORTH 500 WEST_PROVO_UT
# 1836  CANONSBURG GENERAL HOSPITAL_100 MEDICAL BOULEV...
# 2438  BETH ISRAEL DEACONESS HOSPITAL - PLYMOUTH_275 ...
# 1971  ST FRANCIS MEDICAL CENTER_309 JACKSON STREET_M...
# 1970  ST FRANCIS MEDICAL CENTER_309 JACKSON STREET_M...
#
#                               Reimbursement_Name_Lookup
# 2675  CLAIBORNE MEDICAL CENTER_1850 OLD KNOXVILLE HI...
# 1987  LAKE CHARLES MEMORIAL HOSPITAL_1701 OAK PARK B...
# 1045  VALLEY PRESBYTERIAN HOSPITAL_15107 VANOWEN ST_...
# 2319  UNIVERSITY COLO HEALTH MEMORIAL HOSPITAL CENTR...
# 2526  NEW YORK METHODIST HOSPITAL_506 SIXTH STREET_B...
# ...                                                 ...
# 2093  UTAH VALLEY HOSPITAL_1034 NORTH 500 WEST_PROVO_UT
# 1836  CANONSBURG GENERAL HOSPITAL_100 MEDICAL BOULEV...
# 2438  BETH ISRAEL DEACONESS HOSPITAL - PLYMOUTH_275 ...
# 1971  ST FRANCIS MEDICAL CENTER_309 JACKSON STREET_M...
# 1970  UNIVERSITY HEALTH CONWAY_4864 JACKSON STREET_M...
#
# [2751 rows x 5 columns]

# %%
# If you need to save it to Excel -
#final_merge.sort_values(by=['Account_Num', 'Score'],
#                        ascending=False).to_excel('merge_list.xlsx',
#                                                  index=False)

# %%
final_merge[final_merge['Account_Num']==11035][cols]
# Out:
#       Account_Num  Provider_Num  Score  \
# 2316        11035        550921    2.0
# 2317        11035        706807    3.0
#
#                                      Acct_Name_Lookup  \
# 2316  SAINT JOSEPH HOSPITAL_1375 E 19TH AVE_DENVER_CO
# 2317  SAINT JOSEPH HOSPITAL_1375 E 19TH AVE_DENVER_CO
#
#                               Reimbursement_Name_Lookup
# 2316  PRESBYTERIAN ST LUKES MEDICAL CENTER_1719 E 19...
# 2317  SAINT JOSEPH HOSPITAL_1375 EAST 19TH AVE_DENVE...

# %%
final_merge[final_merge['Account_Num']==56375][cols]
# Out:
#      Account_Num  Provider_Num  Score  \
# 155        56375        390402    2.0
# 156        56375        451229    3.0
#
#                                       Acct_Name_Lookup  \
# 155  BROWARD HEALTH IMPERIAL POINT_6401 N FEDERAL H...
# 156  BROWARD HEALTH IMPERIAL POINT_6401 N FEDERAL H...
#
#                              Reimbursement_Name_Lookup
# 155  HOLY CROSS HOSPITAL_4725 N FEDERAL HWY_FORT LA...
# 156  BROWARD HEALTH IMPERIAL POINT_6401 N FEDERAL H...

# %% [markdown]
# ### then dedupe the data, as this package allows this

# %%
hospital_dupes = pd.read_csv(
    'https://github.com/chris1610/pbpython/raw/master/data/hospital_account_dupes.csv',
    index_col='Account_Num')

# %%
hospital_dupes.head()
# Out:
#                                  Facility Name                    Address  \
# Account_Num
# 71730                   SAGE MEMORIAL HOSPITAL  STATE ROUTE 264 SOUTH 191
# 70116              WOODRIDGE BEHAVIORAL CENTER       600 NORTH 7TH STREET
# 87991                 DOUGLAS GARDENS HOSPITAL            5200 NE 2ND AVE
# 22662        SUNCOAST BEHAVIORAL HEALTH CENTER             4480 51ST ST W
# 63165                 TREASURE VALLEY HOSPITAL   8800 WEST EMERALD STREET
#
#                      City State  ZIP Code County Name    Phone Number  \
# Account_Num
# 71730              GANADO    AZ     86505      APACHE  (928) 755-4541
# 70116        WEST MEMPHIS    AR     72301  CRITTENDEN  (870) 394-4113
# 87991               MIAMI    FL     33137  MIAMI-DADE  (305) 751-8626
# 22662           BRADENTON    FL     34210     MANATEE  (941) 792-2222
# 63165               BOISE    ID     83704         ADA  (208) 373-5000
#
#                          Hospital Type              Hospital Ownership
# Account_Num
# 71730        Critical Access Hospitals  Voluntary non-profit - Private
# 70116                      Psychiatric                     Proprietary
# 87991             Acute Care Hospitals  Voluntary non-profit - Private
# 22662                      Psychiatric                     Proprietary
# 63165             Acute Care Hospitals                     Proprietary

# %%
# Deduping follows the same process, you just use 1 single dataframe
dupe_indexer = recordlinkage.Index()
dupe_indexer.sortedneighbourhood(left_on='State')
dupe_candidate_links = dupe_indexer.index(hospital_dupes)

# %%
# Comparison step
compare_dupes = recordlinkage.Compare()
compare_dupes.string('City', 'City', threshold=0.85, label='City')
compare_dupes.string('Phone Number',
                     'Phone Number',
                     threshold=0.85,
                     label='Phone_Num')
compare_dupes.string('Facility Name',
                     'Facility Name',
                     threshold=0.80,
                     label='Hosp_Name')
compare_dupes.string('Address',
                     'Address',
                     threshold=0.85,
                     label='Hosp_Address')
dupe_features = compare_dupes.compute(dupe_candidate_links, hospital_dupes)

# %%
dupe_features
# Out:
#                              City  Phone_Num  Hosp_Name  Hosp_Address
# Account_Num_1 Account_Num_2
# 26270         28485           0.0        0.0        0.0           0.0
#               30430           0.0        0.0        0.0           0.0
#               43602           0.0        0.0        0.0           0.0
# 59585         28485           0.0        0.0        0.0           0.0
#               30430           0.0        0.0        0.0           0.0
# ...                           ...        ...        ...           ...
# 64029         38600           0.0        0.0        0.0           0.0
#               35413           0.0        0.0        0.0           0.0
#               81525           0.0        0.0        0.0           0.0
#               82916           0.0        0.0        0.0           0.0
#               18907           0.0        0.0        0.0           0.0
#
# [981277 rows x 4 columns]

# %%
dupe_features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 3.0         7
# 2.0       206
# 1.0      7859
# 0.0    973205
# dtype: int64

# %%
potential_dupes = dupe_features[dupe_features.sum(axis=1) > 2].reset_index()
potential_dupes['Score'] = potential_dupes.loc[:, 'City':'Hosp_Address'].sum(axis=1)

# %%
potential_dupes.sort_values(by=['Score'], ascending=True)
# Out:
#    Account_Num_1  Account_Num_2  City  Phone_Num  Hosp_Name  Hosp_Address  \
# 0          28494          37949   1.0        1.0        0.0           1.0
# 1          74835          77000   1.0        1.0        0.0           1.0
# 2          24549          28485   1.0        1.0        0.0           1.0
# 3          70366          52654   1.0        1.0        0.0           1.0
# 4          61685          24849   1.0        1.0        0.0           1.0
# 5          51567          41166   1.0        1.0        1.0           0.0
# 6          26495          41079   1.0        1.0        0.0           1.0
#
#    Score
# 0    3.0
# 1    3.0
# 2    3.0
# 3    3.0
# 4    3.0
# 5    3.0
# 6    3.0

# %%
# Take a look at one of the potential duplicates
hospital_dupes[hospital_dupes.index.isin([51567, 41166])]
# Out:
#                       Facility Name                 Address       City State  \
# Account_Num
# 41166           ST VINCENT HOSPITAL      835 S VAN BUREN ST  GREEN BAY    WI
# 51567        SAINT VINCENT HOSPITAL  835 SOUTH VAN BUREN ST  GREEN BAY    WI
#
#              ZIP Code County Name    Phone Number         Hospital Type  \
# Account_Num
# 41166           54301       BROWN  (920) 433-0111  Acute Care Hospitals
# 51567           54301       BROWN  (920) 433-0112  Acute Care Hospitals
#
#                         Hospital Ownership
# Account_Num
# 41166        Voluntary non-profit - Church
# 51567        Voluntary non-profit - Church
